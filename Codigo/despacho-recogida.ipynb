# %% [markdown]
# # Apertura del archivo "Plantilla Real a Liquidar Transporte" creación del dataframe "FLETES"y su depuración

# %%
# importarción de librerias que se van a utilizar.
import pandas as pd
import numpy as np

# definición del path del archivo y la hoja la cual se va a traer y depurar.
str_ruta = r'C:\Users\Admin\Desktop\Liquidar\Archivo Base\PLANTILLA REAL A LIQUIDAR  TRANSPORTES FINAL.xlsx'
str_nombre_hoja = 'FLETES'

# creación del dataframe de la hoja "FLETES"
df_fletes = pd.read_excel(str_ruta, sheet_name=str_nombre_hoja)

# Depuración de las columnas para eliminar valores invalidos
columnas_tipo_texto = ['punto', 'tipo_despacho', 'pedido', 'identificacion', 'contacto', 'nombre_completo', 'nombre_ciudad', 'codigo_flete', 'usuario_pedido', 'dato_adicional_pedido', 'articulos', 'documentos1', 'documentos2', 'tipo_ubicacion', 'placa', 'nombre_conductor', 'transportador', 'nombre_transportador', 'clasificador1', 'soporte', 'proveedor', 'usuario_insercion', 'CONCATENAR PESO,PROVEEDOR ', 'CIUDA', 'DEPARTAMENTO', 'PUNTO ORIGEN ', 'RANGO VOLUMEN', 'RANGOPESO ', 'PESO COTIZADO ', 'VOLUMEN COTIZADO ']
columnas_tipo_numero = ['entrega', 'despacho', 'salida', 'codigo', 'departamento', 'ciudad', 'ruta_terrestre', 'total_peso', 'total_volumen', 'peso_cotizado', 'volumen_cotizado', 'cajas_cotizado', 'valor_mercancia', 'tiempo_real', 'demora', 'numero_guia']

for columna in columnas_tipo_texto:
    df_fletes[columna] = df_fletes[columna].fillna("")

for columna in columnas_tipo_numero:
    df_fletes[columna] = pd.to_numeric(df_fletes[columna], errors='coerce').replace(np.nan, 0, regex=True)

# Creación de nueva columna y conversión de la columna de "fecha_entrega" con formato fecha con hora a nueva columna "fecha_entrega_dia" con formato año-mes-día
df_fletes['fecha_entrega_dia'] = df_fletes['fecha_entrega'].dt.date

# Creación de nuevas columnas necesarias dentro del dataframe
df_fletes['tipo']=""
df_fletes['tipo_ruta']=""
df_fletes['validacion_24h']=""
df_fletes['valor_bot']=""
df_fletes['valor_original_bot']=""
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL72 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL73 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL74 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL75 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL76 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL77 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL78 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL79 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL236 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL237 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL238 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL239 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL255 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL256 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL257 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL540 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL541 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL542 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL543 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL544 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL545 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL546 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL547 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL548 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL549 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL550 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL551 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL552 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL553 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL554 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL555 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL556 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL557 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL558 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL559 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL560 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL561 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL562 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL563 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL564 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL565 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL566 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL567 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL568 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell Y569 is marked as a date but the serial value 3175137229 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL569 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL570 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL571 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell Y572 is marked as a date but the serial value 3175137229 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL572 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL573 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL574 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL575 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL576 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL577 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL578 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL579 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL580 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL581 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL582 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL583 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL584 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell Y585 is marked as a date but the serial value 3175137229 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL585 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL941 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL942 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL943 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL944 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL967 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL968 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL977 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL1174 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL1175 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL1176 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL1177 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL1178 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL1179 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL1180 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL1181 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL1182 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL1183 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL1184 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL1185 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL1186 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL1187 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL1188 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL1189 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL1190 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL1191 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL1192 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL1193 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL1249 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL1250 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL1251 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL1252 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL1253 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL1269 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL1270 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL1707 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL1708 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL1709 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL1710 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL1975 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL1976 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL1977 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL1978 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL1979 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL1980 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL1981 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL1982 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL1983 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL1984 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL1985 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL1986 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL1987 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL1988 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL1989 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL1990 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2121 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2122 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2123 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2124 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2125 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2126 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2127 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2128 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2129 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2149 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2150 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2151 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2152 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2153 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2154 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2155 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2156 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2157 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2158 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2159 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2160 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2161 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2162 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2163 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2193 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2194 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2195 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2196 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2197 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2200 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2201 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2202 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2203 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2204 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2205 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2206 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2207 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2208 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2209 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2210 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2211 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2212 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2213 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2245 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2246 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2247 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2248 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2249 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2250 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2251 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2256 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2270 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2271 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2272 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2297 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2298 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2299 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2300 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2301 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2302 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2303 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2304 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2305 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2306 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2307 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2308 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2309 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2310 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2311 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2312 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2313 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2314 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2315 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2316 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2317 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2422 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2423 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2424 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2425 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2426 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2427 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2428 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2429 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2430 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2431 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2432 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2433 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2434 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2435 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2436 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2437 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell Y2699 is marked as a date but the serial value 3183490254 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell Y2700 is marked as a date but the serial value 3183490254 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell Y2715 is marked as a date but the serial value 3167535929 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell Y2716 is marked as a date but the serial value 3167535929 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell Y2717 is marked as a date but the serial value 3023254307 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell Y2718 is marked as a date but the serial value 3023254307 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell Y2719 is marked as a date but the serial value 3104373272 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell Y2720 is marked as a date but the serial value 3104373272 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell Y2737 is marked as a date but the serial value 3104269211 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell Y2738 is marked as a date but the serial value 3104269211 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2801 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell AL2802 is marked as a date but the serial value 901623528 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell Y2978 is marked as a date but the serial value 3023684392 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell Y2979 is marked as a date but the serial value 3023684392 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell Y2980 is marked as a date but the serial value 3023684392 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell Y2981 is marked as a date but the serial value 3023684392 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell Y2982 is marked as a date but the serial value 3023684392 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell Y3091 is marked as a date but the serial value 3163522463 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell Y3092 is marked as a date but the serial value 3163522463 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell Y3096 is marked as a date but the serial value 3166184304 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell Y3097 is marked as a date but the serial value 3166184304 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell Y3159 is marked as a date but the serial value 3162982821 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:223: UserWarning: Cell Y3160 is marked as a date but the serial value 3162982821 is outside the limits for dates. The cell will be treated as an error.
#   warn(msg)

# %% [markdown]
# # Creación de dataframes con valores estandares

# %%
# definición de las hojas que serán traidas.
str_nombre_hoja2 = 'TIPO RUTA'
str_nombre_hoja3 = 'TARIFA CLIENTE'
str_nombre_hoja4 = 'TARIFA PROVEEDOR'
str_nombre_hoja5 = 'TARIFA P y V'
str_nombre_hoja6 = 'CODIGO FLETE'

# creación de los dataframes con valores estandarizados que serán necesarios.
df_tipo_ruta = pd.read_excel(str_ruta, sheet_name=str_nombre_hoja2)
df_tarifa_cliente = pd.read_excel(str_ruta, sheet_name=str_nombre_hoja3)
df_tarifa_proveedor = pd.read_excel(str_ruta, sheet_name=str_nombre_hoja4)
df_tarifa_pv = pd.read_excel(str_ruta, sheet_name=str_nombre_hoja5)
df_codigo_flete = pd.read_excel(str_ruta, sheet_name=str_nombre_hoja6)

# %% [markdown]
# # Asignación de tipo de ruta a la columna "tipo_ruta"

# %%
# Definición de todos las filas con la palabra "PERIFERIA"
df_fletes['tipo_ruta'] = 'PERIFERIA'

# Iteración a través de las filas del dataframe df_fletes y comparación con el dataframe df_tipo_ruta
for i, fila in df_fletes.iterrows():
    punto = fila['punto']
    ciudad = fila['nombre_ciudad']
    
    # Verificación de coincidencias en df_tipo_ruta y asignación de la palabra "LOCAL" en las filas necesarias
    if any((df_tipo_ruta['CEDIS'] == punto) & (df_tipo_ruta['CIUDAD'] == ciudad)):
        df_fletes.at[i, 'tipo_ruta'] = 'LOCAL'

# %% [markdown]
# # Agrupación de datos para rutas locales de tipo despacho y recogida

# %%
# Creación de grupos por respectivos filtros para despachos y recogidas
filtro = (df_fletes['tipo_ruta'] == 'LOCAL') & ((df_fletes['tipo_despacho'] == 'DESPACHO') | (df_fletes['tipo_despacho'] == 'RECOGIDA'))
df_dr_locales = df_fletes[filtro].groupby(['punto', 'fecha_entrega', 'proveedor', 'identificacion'])


# Tipos de despachos que hay por cada una de las agrupaciones
valores_unicos_despachos = df_dr_locales['tipo_despacho'].apply(lambda x: x.unique())

############ Descomentar si se desea ver los grupos ################
"""for indice, datos in df_grupo_locales:
  print("....indice={}".format(indice))
  print("--------datos-------")
  print(datos)"""
# Out:
# 'for indice, datos in df_grupo_locales:\n  print("....indice={}".format(indice))\n  print("--------datos-------")\n  print(datos)'

# %% [markdown]
# # Clasificación de cada grupo por tipo de despacho

# %%
# Conversión de los tipos de despacho por grupo a un dataframe para su mejor manipulación
df_tipo_liquidar = valores_unicos_despachos.to_frame(name='tipo')

# Creación de nueva columna dentro del dataframe df_tipo_grupo_ruta
df_tipo_liquidar["tipo_grupo_ruta"] = ""
df_tipo_liquidar["numero_despachos"] = ""
df_tipo_liquidar["transportador"] = ""
df_tipo_liquidar['codigos_flete'] = ""

# Función para clasasificar los grupos por tipos de despacho
def asignar_valor(row):
    if set(row['tipo']) == set(['DESPACHO']):
        return 1
    elif set(row['tipo']) == set(['RECOGIDA']):
        return 2
    elif set(row['tipo']) == set(['RECOGIDA','DESPACHO']):
        return 3
    else:
        return 0

# Asignación de la clasificación a la columna "tipo_grupo_ruta" dentro del dataframe df_tipo_grupo_ruta 
df_tipo_liquidar['tipo_grupo_ruta'] = df_tipo_liquidar.apply(asignar_valor, axis=1)

# %%
# conteo de despachos por agrupación
conteo_despacho = df_dr_locales['despacho'].agg(lambda x: x.nunique())
conteo_a_lista = conteo_despacho.tolist()

# Asignación de conteo a dataframe df_tipo_grupo_ruta
df_tipo_liquidar['numero_despachos'] = conteo_a_lista

# valor de transportador por despacho
valores_transportador = df_dr_locales['transportador'].apply(lambda x: x.unique())
valores_a_lista = valores_transportador.tolist()

# Asignación de valores a dataframe df_tipo_grupo_ruta
df_tipo_liquidar['transportador'] = valores_a_lista

# valores de codigo de flete por despacho cada despacho
valores_codigo_flete = df_dr_locales['codigo_flete'].apply(lambda x: x.unique())
valores_codigo_a_lista = valores_codigo_flete.tolist()

# Asignación de valores a dataframe df_tipo_grupo_ruta
df_tipo_liquidar['codigos_flete'] = valores_codigo_a_lista
